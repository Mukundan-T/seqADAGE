# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukundan-T/seqADAGE/blob/master/Mukundan_pathway_enrichment_kegg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model Evaluation - Pathway Enrichment Analysis
#
# ### Mukundan Thanigaivelan
#
# ### June 12, 2026
#
# This notebook performs pathway enrichment analysis for the E. coli and S. aureus genes.
