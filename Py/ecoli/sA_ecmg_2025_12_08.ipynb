# %%
import run_model_preT
import run_model
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#from imp import reload
from importlib import reload
import Adage
from scipy.stats import hypergeom
import csv
import time
import random
# Out:
# True

# %%
import tensorflow as tf

print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())

# %% [markdown]
# ## Base features (from ADAGE)
#
# For the sake of this efficiency, starting with the following parameters:
#
# * hidden features: 300
# * epochs: 500
# * curruption: 0.01
# * batchs zie: 10
# * validatoin split: 0.1
# * activation: sigmoid
# * objective: binary cross-entropy

# %%
#adage_comp = pandas.read_csv('data_files/ADAGE_compendium.csv')
all_comp = pd.read_csv('../data_files/ecmg_lcn01.csv', index_col = 0)
gene_num = np.size(all_comp, 0)
samp_num = np.size(all_comp, 1)
print(gene_num, samp_num)
#fig = sns.histplot(pd.melt(all_comp), bins = 50)
# Out:
# 4272 16150

# %%
669 - 571
# Out:
# 98

# %%
comps = ["ecmg_lcn01.csv"]


model_dict_post = {}

stime = time.time()
ltime = 0
c = 0



seeds = list(range(99,100))
#seeds = random.sample(range(10000), 10)

for comp in comps:
    for seed in seeds:
        name = 'ad_' + comp + '_2025_09_01_' + str(seed+571)
        print(name)
        ttime = time.time()
        mseq = run_model.run_model('../data_files/ecmg_lcn01.csv',
                                                  seed=seed+571,
                                                  enc_dim = 450,
                                                  kl1=0,
                                                  kl2=0,
                                                  act = "tanh",
                                                  act2="tanh",
                                                  tied = True,
                                                  epochs=100,
                                                  init="glorot_uniform",
                                                  batch_size=15,
                                                  dropout = 0,
                                                  mm = 0.6,
                                                  lr = 0.5)
       
        model_dict_post[name] = mseq
        ltime = ((time.time() - ttime) + ltime)
        c+=1

rtime = time.time() - stime
# Out:
# ad_ecmg_lcn01.csv_2025_09_01_670
# tied
# Epoch 1/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0181 - val_loss: 0.0134
# Epoch 2/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0130 - val_loss: 0.0127
# Epoch 3/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0125 - val_loss: 0.0124
# Epoch 4/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 5/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0120 - val_loss: 0.0120
# Epoch 6/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0118 - val_loss: 0.0118
# Epoch 7/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 8/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0116 - val_loss: 0.0117
# Epoch 9/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 10/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 11/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 12/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 13/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 14/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 15/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 16/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 17/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 18/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 19/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 20/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 21/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 22/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 23/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 24/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 25/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 26/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 27/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 28/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 29/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 30/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 31/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 32/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 33/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 34/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 35/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 36/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 37/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 38/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 39/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 40/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 41/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 42/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 43/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 44/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 45/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 46/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 47/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 48/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 49/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 50/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 51/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 52/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 53/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 54/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 55/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 56/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 57/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 58/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 59/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 60/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 61/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 62/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 63/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 64/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 65/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 66/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 67/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 68/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 69/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 70/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 71/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 72/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 73/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 74/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 75/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 76/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 77/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 78/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 79/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 80/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 81/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 82/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 83/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 84/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 85/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 86/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 87/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 88/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 89/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 90/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 91/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 92/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 93/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 94/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 95/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 96/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 97/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 98/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 99/100
# 969/969 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 100/100
# 633/969 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0103

# %%
comps = ["ecmg_lcn01"]





model_dict_post = {}

stime = time.time()
ltime = 0
c = 0



seeds = list(range(650,100))
#seeds = random.sample(range(10000), 10)

for comp in comps:
    for seed in seeds:
        name = 'ad_' + comp + '_2025_09_01_' + str(seed+571)
        print(name)
        ttime = time.time()
        mseq = run_model.run_model('../data_files/ecmg_lcn01.csv',
                                                  seed=seed+571,
                                                  enc_dim = 450,
                                                  kl1=0,
                                                  kl2=0,
                                                  act = "tanh",
                                                  act2="tanh",
                                                  tied = True,
                                                  epochs=100,
                                                  init="glorot_uniform",
                                                  batch_size=15,
                                                  dropout = 0,
                                                  mm = 0.6,
                                                  lr = 0.5)
       
        model_dict_post[name] = mseq
        ltime = ((time.time() - ttime) + ltime)
        c+=1

rtime = time.time() - stime

# %%
print(rtime)
print(c)
print(ltime / c)
print(rtime / 60)
# Out:
# 0.00024509429931640625
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 print(rtime)
#       2 print(c)
# ----> 3 print(ltime / c)
#       4 print(rtime / 60)
#
# ZeroDivisionError: division by zero

# %%
len(comps)

# %%
model_dict = model_dict_post

xd = len(comps) + 1
yd = len(seeds)
fig, ax = plt.subplots(xd, yd,figsize=(xd*10 ,yd *1))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0


for comp in comps:
    xi=0
    for seed in seeds:
        name = 'ad_' + comp + '_2025_09_01_' + str(seed+571)
        model_temp = model_dict[name]
        ax[yi,xi].plot(list(range(0,100)), model_temp.loss, linewidth=1, markersize=2, color = 'orange')
        ax[yi,xi].plot(list(range(0,100)), model_temp.val_loss, linewidth=1, markersize=2, color = 'red')
        ax[yi,xi].set(title = name, xlabel = 'Epochs', ylabel = 'Loss')
        xi+=1
    yi+=1

# %%
model_dict = model_dict_pre

xd = len(comps)
yd = len(seeds)
fig, ax = plt.subplots(xd, yd,figsize=(xd*3 ,yd *5))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0


for comp in comps:
    xi=0
    for seed in seeds:
        name = 'ad_' + comp + '_2025_08_15_' + str(seed+571)
        model_temp = model_dict[name]
        ax[yi,xi].plot(list(range(0,10)), model_temp.loss, linewidth=1, markersize=2, color = 'orange')
        ax[yi,xi].plot(list(range(0,10)), model_temp.val_loss, linewidth=1, markersize=2, color = 'red')
        ax[yi,xi].set(title = name, xlabel = 'Epochs', ylabel = 'Loss')
        xi+=1
    yi+=1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.005, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2CTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2CTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_pre[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_preCTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
model_temp = model_dict_seq2
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_seq2[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_seq2[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done') 

model_temp = model_dict_seq2CTRL
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_seq2CTRL[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_seq2CTRL[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done') 


model_temp = model_dict_pre
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_pre[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_pre[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done')


model_temp = model_dict_preCTRL
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_preCTRL[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_preCTRL[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done')

# %%
plimk=5
plimg=5
plimr=5
plimo=5
xd=2
yd=2
fig, ax = plt.subplots(xd,yd,figsize=(xd*8 ,yd *8))
#x = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(0) > 0).sum()
#y = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(1) > 0).sum()
#ax[0,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,0].set(title = 'KEGG', xlabel = 'Total Paths', ylabel = 'Sigs with Paths')

#x = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(1) > 0).sum()
#ax[0,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,1].set(title = 'GO', xlabel = 'Total BP', ylabel = 'Sigs with BP')

#x = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(1) > 0).sum()
#ax[1,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,0].set(title = 'Regulons', xlabel = 'Total Regs', ylabel = 'Sigs with Regs')

#x = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(1) > 0).sum()
#ax[1,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,1].set(title = 'Operons', xlabel = 'Total Operons', ylabel = 'Sigs with Operons')

xi = 0
yi = 0
c = 'grey'

# edge color is tied or unties
ec = ['black','red','blue','green','purple']
eci=0

# shape is activation function
ms = ['.','s', '^','h']
mi=0

# size is L1 norm
s=50

for seed in range(1):
    for i in inits:
        s=100
    #print(i)
        for l in L1_norm:
            xi=0
            mi=0
        #print(l)
            for a in act_fun:
                m = ms[mi]
                eci=0
            #print(a)
                for t in tied:
                    name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                    print(name)
                    model_temp = model_dict_seq2[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax[0,0].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    #model_temp = model_dict_seq2CTRL[name]
                    #x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    #y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    #ax[0,1].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_pre[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax[1,0].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    #model_temp = model_dict_preCTRL[name]
                    #x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    #y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    #ax[1,1].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    #eci = eci+1
                mi = mi+1
            s=s+250
        c = 'grey'

# %%
plimk=5
plimg=5
plimr=5
plimo=5
xd=1
yd=1
fig, ax = plt.subplots(xd,yd,figsize=(xd*8 ,yd *8))
#x = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(0) > 0).sum()
#y = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(1) > 0).sum()
#ax[0,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,0].set(title = 'KEGG', xlabel = 'Total Paths', ylabel = 'Sigs with Paths')

#x = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(1) > 0).sum()
#ax[0,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,1].set(title = 'GO', xlabel = 'Total BP', ylabel = 'Sigs with BP')

#x = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(1) > 0).sum()
#ax[1,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,0].set(title = 'Regulons', xlabel = 'Total Regs', ylabel = 'Sigs with Regs')

#x = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(1) > 0).sum()
#ax[1,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,1].set(title = 'Operons', xlabel = 'Total Operons', ylabel = 'Sigs with Operons')

xi = 0
yi = 0
c = 'grey'

# edge color is tied or untied
ec = ['black','red','blue','green','purple']
eci=0

# shape is activation function
ms = ['.','s', '^','h']
mi=0

# size is L1 norm
s=50

for seed in range(1):
    for i in inits:
        s=100
    #print(i)
        for l in L1_norm:
            xi=0
            mi=0
        #print(l)
            for a in act_fun:
                m = ms[mi]
                eci=0
            #print(a)
                for t in tied:
                    name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                    print(name)
                    model_temp = model_dict_seq2[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'grey', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_seq2CTRL[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'pink', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_pre[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'black', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_preCTRL[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'red', marker = m, edgecolor = ec[eci], s=s)
                    eci = eci+1
                mi = mi+1
            s=s+250
        c = 'grey'
