# %%
import run_model_preT
import run_model
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#from imp import reload
from importlib import reload
import Adage
from scipy.stats import hypergeom
import csv
import time

# %%
import tensorflow as tf

print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())
# Out:
# Num CPUs Available:  1
# Num GPUs Available:  0
# True
# 2025-08-15 14:10:59.712836: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# for dev purposes, while updating run_model.py need to reload
# for dev purposes, while updating run_model.py need to reload
reload(run_model_preT)
reload(run_model)
reload(Adage)
# Out:
# <module 'Adage' from '/hpc/group/ohlab/doingg/seqADAGE/Py/Adage.py'>

# %%
run_model_preT.tune_model('../data_files/ecoli_MG165_genome_part2_log_counts_norm_01.csv',100)

# %% [markdown]
# ## Base features (from ADAGE)
#
# For the sake of this efficiency, starting with the following parameters:
#
# * hidden features: 300
# * epochs: 500
# * curruption: 0.01
# * batchs zie: 10
# * validatoin split: 0.1
# * activation: sigmoid
# * objective: binary cross-entropy

# %%
#adage_comp = pandas.read_csv('data_files/ADAGE_compendium.csv')
all_comp = np.loadtxt(open('../data_files/ecoli_pan_genome_log_counts_norm_01_nonames.csv', "rb"),delimiter=',',skiprows = 1)
gene_num = np.size(all_comp, 0)
samp_num = np.size(all_comp, 1)
print(gene_num, samp_num)
fig = sns.histplot(all_comp.flatten(), bins = 50)

# %%
#adage_comp = pandas.read_csv('data_files/ADAGE_compendium.csv')
all_comp = np.loadtxt(open('../data_files/ecoli_MG165_genome_part2_log_counts_norm_01_nonames.csv', "rb"),delimiter=',',skiprows = 1)
gene_num = np.size(all_comp, 0)
samp_num = np.size(all_comp, 1)
print(gene_num, samp_num)
fig = sns.histplot(all_comp.flatten(), bins = 50)
# Out:
# 4272 15087

# %%
comps = ["ecoli_MG165_genome_part2_log_counts_norm_01"]





model_dict_post = {}

stime = time.time()
ltime = 0
c = 0



seeds = list(range(10))

for comp in comps:
    for seed in seeds:
        name = 'ad_' + comp + '_2025_09_01_' + str(seed+571)
        print(name)
        ttime = time.time()
        mseq = run_model.run_model('../data_files/ecoli_MG165_genome_part2_log_counts_norm_01.csv',
                                                  seed=seed+571,
                                                  enc_dim = 450,
                                                  kl1=0,
                                                  kl2=0,
                                                  act = "tanh",
                                                  act2="tanh",
                                                  tied = True,
                                                  epochs=100,
                                                  init="glorot_uniform",
                                                  batch_size=15,
                                                  dropout = 0,
                                                  mm = 0.6,
                                                  lr = 0.5)
       
        model_dict_post[name] = mseq
        ltime = ((time.time() - ttime) + ltime)
        c+=1

rtime = time.time() - stime
# Out:
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_571
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0178 - val_loss: 0.0131
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0127 - val_loss: 0.0125
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 42/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 43/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 44/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 45/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 46/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 47/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 48/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 49/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 50/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 51/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 52/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 53/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 54/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 55/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 56/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 57/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 58/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 59/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 60/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 61/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 62/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 63/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 64/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 65/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 66/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 67/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 68/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 69/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 70/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 71/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 72/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 73/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 74/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 75/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 76/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 77/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 78/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 79/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 80/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 81/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 82/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 83/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 84/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 85/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 86/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 87/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 88/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 89/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 90/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 91/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 92/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 93/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 94/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 95/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 96/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 97/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 98/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 99/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 100/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# fitted
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_572
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0179 - val_loss: 0.0131
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0127 - val_loss: 0.0125
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0115 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0114 - val_loss: 0.0114
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 42/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 43/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 44/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 45/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 46/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 47/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 48/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 49/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 50/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 51/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 52/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 53/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 54/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 55/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 56/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 57/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 58/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 59/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 60/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 61/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 62/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 63/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 64/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 65/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 66/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 67/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 68/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 69/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 70/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 71/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 72/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 73/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 74/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 75/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 76/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 77/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 78/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 79/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 80/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 81/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 82/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 83/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 84/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 85/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 86/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 87/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 88/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 89/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 90/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 91/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 92/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 93/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 94/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 95/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 96/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 97/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 98/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 99/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 100/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0104
# fitted
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_573
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0177 - val_loss: 0.0131
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0127 - val_loss: 0.0125
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0116 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 42/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 43/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 44/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 45/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 46/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 47/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 48/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 49/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 50/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 51/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 52/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 53/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 54/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 55/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 56/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 57/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 58/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 59/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 60/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 61/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 62/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 63/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 64/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 65/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 66/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 67/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 68/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 69/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 70/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 71/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 72/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 73/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 74/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 75/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 76/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 77/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 78/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 79/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 80/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 81/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 82/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 83/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 84/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 85/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 86/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 87/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 88/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 89/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 90/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 91/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 92/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 93/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 94/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 95/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 96/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 97/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 98/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 99/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 100/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# fitted
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_574
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0179 - val_loss: 0.0132
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0122 - val_loss: 0.0122
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0115
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 42/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 43/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 44/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 45/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 46/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 47/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 48/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 49/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 50/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 51/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 52/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 53/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 54/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 55/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 56/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 57/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 58/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 59/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 60/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 61/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 62/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 63/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 64/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 65/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 66/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 67/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 68/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 69/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 70/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 71/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 72/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 73/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 74/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 75/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 76/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 77/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 78/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 79/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 80/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 81/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 82/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 83/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 84/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 85/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 86/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 87/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 88/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 89/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 90/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 91/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 92/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 93/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 94/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 95/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 96/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 97/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 98/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 99/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 100/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# fitted
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_575
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0176 - val_loss: 0.0131
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0127 - val_loss: 0.0125
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 42/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 43/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 44/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 45/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 46/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 47/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 48/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 49/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 50/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 51/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 52/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 53/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 54/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 55/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 56/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 57/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 58/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 59/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 60/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 61/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 62/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 63/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 64/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 65/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 66/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 67/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 68/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 69/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 70/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 71/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 72/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 73/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 74/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 75/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 76/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 77/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 78/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 79/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 80/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 81/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 82/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 83/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 84/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 85/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 86/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 87/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 88/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 89/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 90/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 91/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 92/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 93/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 94/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 95/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 96/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 97/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 98/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 99/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 100/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0101 - val_loss: 0.0105
# fitted
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_576
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0177 - val_loss: 0.0132
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0116 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0115
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# ...
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 82/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 83/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 84/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 85/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 86/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 87/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 88/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 89/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 90/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 91/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 92/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 93/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 94/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 95/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 96/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 97/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 98/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 99/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 100/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# fitted
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_579
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0180 - val_loss: 0.0131
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0128 - val_loss: 0.0124
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0114 - val_loss: 0.0114
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 42/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 43/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 44/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 45/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 46/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 47/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 48/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 49/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 50/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 51/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 52/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 53/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 54/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 55/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 56/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 57/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 58/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 59/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 60/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 61/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 62/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 63/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 64/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 65/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 66/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 67/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 68/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 69/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 70/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 71/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 72/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 73/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 74/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 75/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 76/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 77/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 78/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 79/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 80/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 81/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 82/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 83/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 84/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 85/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 86/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 87/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 88/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 89/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 90/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0102 - val_loss: 0.0105
# Epoch 91/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 92/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 93/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 94/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 95/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 96/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 97/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 98/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 99/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 100/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.0101 - val_loss: 0.0105
# fitted
# ad_ecoli_MG165_genome_part2_log_counts_norm_01_2025_09_01_580
# tied
# Epoch 1/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0179 - val_loss: 0.0131
# Epoch 2/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 3/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 4/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 5/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0117 - val_loss: 0.0117
# Epoch 6/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0116 - val_loss: 0.0116
# Epoch 7/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0114 - val_loss: 0.0115
# Epoch 8/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 9/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 10/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 11/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 12/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 13/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 14/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 15/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 16/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 18/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 20/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 21/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 22/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 23/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 24/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0108 - val_loss: 0.0109
# Epoch 25/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 26/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 27/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 28/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 29/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 30/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 31/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 32/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 33/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 35/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 36/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 37/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 38/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 40/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 23s 25ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 41/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 42/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 43/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 44/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 45/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 46/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 47/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 48/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 49/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 50/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 51/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 52/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 53/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 54/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 55/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 56/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 57/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 58/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 59/100
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 60/100
# 554/906 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0103

# %%
print(rtime)
print(c)
print(ltime / c)
print(rtime / 60)
# Out:
# 7743.768882513046
# 10
# 774.372789645195
# 129.06281470855077

# %%
len(comps)
# Out:
# 1

# %%
model_dict = model_dict_post

xd = len(comps) + 1
yd = len(seeds)
fig, ax = plt.subplots(xd, yd,figsize=(xd*10 ,yd *1))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0


for comp in comps:
    xi=0
    for seed in seeds:
        name = 'ad_' + comp + '_2025_09_01_' + str(seed+571)
        model_temp = model_dict[name]
        ax[yi,xi].plot(list(range(0,100)), model_temp.loss, linewidth=1, markersize=2, color = 'orange')
        ax[yi,xi].plot(list(range(0,100)), model_temp.val_loss, linewidth=1, markersize=2, color = 'red')
        ax[yi,xi].set(title = name, xlabel = 'Epochs', ylabel = 'Loss')
        xi+=1
    yi+=1

# %%
model_dict = model_dict_pre

xd = len(comps)
yd = len(seeds)
fig, ax = plt.subplots(xd, yd,figsize=(xd*3 ,yd *5))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0


for comp in comps:
    xi=0
    for seed in seeds:
        name = 'ad_' + comp + '_2025_08_15_' + str(seed+571)
        model_temp = model_dict[name]
        ax[yi,xi].plot(list(range(0,10)), model_temp.loss, linewidth=1, markersize=2, color = 'orange')
        ax[yi,xi].plot(list(range(0,10)), model_temp.val_loss, linewidth=1, markersize=2, color = 'red')
        ax[yi,xi].set(title = name, xlabel = 'Epochs', ylabel = 'Loss')
        xi+=1
    yi+=1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.005, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2CTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 15
#      13 name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
#      14 #print(name)
# ---> 15 model_temp = model_dict_seq2CTRL[name]
#      16 for node in range(0,100):
#      17     sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
#      18         ax=ax[xi,yi],
#      19         #hist=True,
#    (...)     23         #rug=False
#      24                 )
#
# NameError: name 'model_dict_seq2CTRL' is not defined

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 17
#      15 model_temp = model_dict_seq2[name]
#      16 for node in range(0,100):
# ---> 17     sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
#      18         ax=ax[xi,yi],
#      19         #hist=True,
#      20         binwidth = 0.01,
#      21         #stat="density",
#      22         kde=False
#      23         #rug=False
#      24                 )
#      25 ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
#      26 ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/seaborn/distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)   1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)   1446         **kwargs,
#    1447     )
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/seaborn/distributions.py:470, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     468 # Do the histogram computation
#     469 if not (multiple_histograms and common_bins):
# --> 470     bin_kws = estimator._define_bin_params(sub_data, orient, None)
#     471 res = estimator._normalize(estimator._eval(sub_data, orient, bin_kws))
#     472 heights = res[estimator.stat].to_numpy()
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/seaborn/_stats/counting.py:152, in Hist._define_bin_params(self, data, orient, scale_type)
#     148 # TODO We'll want this for ordinal / discrete scales too
#     149 # (Do we need discrete as a parameter or just infer from scale?)
#     150 discrete = self.discrete or scale_type == "nominal"
# --> 152 bin_edges = self._define_bin_edges(
#     153     vals, weights, self.bins, self.binwidth, self.binrange, discrete,
#     154 )
#     156 if isinstance(self.bins, (str, int)):
#     157     n_bins = len(bin_edges) - 1
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/seaborn/_stats/counting.py:137, in Hist._define_bin_edges(self, vals, weight, bins, binwidth, binrange, discrete)
#     135     if binwidth is not None:
#     136         bins = int(round((stop - start) / binwidth))
# --> 137     bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
#     139 # TODO warning or cap on too many bins?
#     141 return bin_edges
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:677, in histogram_bin_edges(a, bins, range, weights)
#     476 r"""
#     477 Function to calculate only the edges of the bins used by the `histogram`
#     478 function.
#    (...)    674
#     675 """
#     676 a, weights = _ravel_and_check_weights(a, weights)
# --> 677 bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     678 return bin_edges
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:428, in _get_bin_edges(a, bins, range, weights)
#     425         raise TypeError(
#     426             '`bins` must be an integer, a string, or an array') from e
#     427     if n_equal_bins < 1:
# --> 428         raise ValueError('`bins` must be positive, when an integer')
#     430     first_edge, last_edge = _get_outer_edges(a, range)
#     432 elif np.ndim(bins) == 1:
#
# ValueError: `bins` must be positive, when an integer

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2CTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_pre[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_preCTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
model_temp = model_dict_seq2
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_seq2[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_seq2[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done') 

model_temp = model_dict_seq2CTRL
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_seq2CTRL[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_seq2CTRL[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done') 


model_temp = model_dict_pre
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_pre[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_pre[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done')


model_temp = model_dict_preCTRL
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_preCTRL[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_preCTRL[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done')
# Out:
# ad_glorot_uniform_0_sigmoid_tiedTrue571
# ad_glorot_uniform_0_tanh_tiedTrue571
# ad_glorot_uniform_0_relu_tiedTrue571
# ad_glorot_uniform_1e-05_sigmoid_tiedTrue571
# ad_glorot_uniform_1e-05_tanh_tiedTrue571
# ad_glorot_uniform_1e-05_relu_tiedTrue571
# ad_glorot_normal_0_sigmoid_tiedTrue571
# ad_glorot_normal_0_tanh_tiedTrue571
# ad_glorot_normal_0_relu_tiedTrue571
# ad_glorot_normal_1e-05_sigmoid_tiedTrue571
# ad_glorot_normal_1e-05_tanh_tiedTrue571
# ad_glorot_normal_1e-05_relu_tiedTrue571
# dict done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 16
#       9     #print('kegg done')
#      10     #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt')
#      11     #print('go done')
#      12     #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
#      13     #print('reg done')
#      14 print('dict done')
# ---> 16 model_temp = model_dict_seq2CTRL
#      17 #del model_temp['tf_adage']
#      18 for m in model_temp:
#
# NameError: name 'model_dict_seq2CTRL' is not defined

# %%
plimk=5
plimg=5
plimr=5
plimo=5
xd=2
yd=2
fig, ax = plt.subplots(xd,yd,figsize=(xd*8 ,yd *8))
#x = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(0) > 0).sum()
#y = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(1) > 0).sum()
#ax[0,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,0].set(title = 'KEGG', xlabel = 'Total Paths', ylabel = 'Sigs with Paths')

#x = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(1) > 0).sum()
#ax[0,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,1].set(title = 'GO', xlabel = 'Total BP', ylabel = 'Sigs with BP')

#x = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(1) > 0).sum()
#ax[1,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,0].set(title = 'Regulons', xlabel = 'Total Regs', ylabel = 'Sigs with Regs')

#x = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(1) > 0).sum()
#ax[1,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,1].set(title = 'Operons', xlabel = 'Total Operons', ylabel = 'Sigs with Operons')

xi = 0
yi = 0
c = 'grey'

# edge color is tied or unties
ec = ['black','red','blue','green','purple']
eci=0

# shape is activation function
ms = ['.','s', '^','h']
mi=0

# size is L1 norm
s=50

for seed in range(1):
    for i in inits:
        s=100
    #print(i)
        for l in L1_norm:
            xi=0
            mi=0
        #print(l)
            for a in act_fun:
                m = ms[mi]
                eci=0
            #print(a)
                for t in tied:
                    name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                    print(name)
                    model_temp = model_dict_seq2[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax[0,0].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    #model_temp = model_dict_seq2CTRL[name]
                    #x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    #y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    #ax[0,1].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_pre[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax[1,0].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    #model_temp = model_dict_preCTRL[name]
                    #x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    #y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    #ax[1,1].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    #eci = eci+1
                mi = mi+1
            s=s+250
        c = 'grey'
# Out:
# ad_glorot_uniform_0_sigmoid_tiedTrue571
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 69
#      63 #model_temp = model_dict_seq2CTRL[name]
#      64 #x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
#      65 #y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
#      66 #ax[0,1].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
#      68 model_temp = model_dict_pre[name]
# ---> 69 x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
#      70 y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
#      71 ax[1,0].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
plimk=5
plimg=5
plimr=5
plimo=5
xd=1
yd=1
fig, ax = plt.subplots(xd,yd,figsize=(xd*8 ,yd *8))
#x = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(0) > 0).sum()
#y = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(1) > 0).sum()
#ax[0,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,0].set(title = 'KEGG', xlabel = 'Total Paths', ylabel = 'Sigs with Paths')

#x = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(1) > 0).sum()
#ax[0,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,1].set(title = 'GO', xlabel = 'Total BP', ylabel = 'Sigs with BP')

#x = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(1) > 0).sum()
#ax[1,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,0].set(title = 'Regulons', xlabel = 'Total Regs', ylabel = 'Sigs with Regs')

#x = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(1) > 0).sum()
#ax[1,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,1].set(title = 'Operons', xlabel = 'Total Operons', ylabel = 'Sigs with Operons')

xi = 0
yi = 0
c = 'grey'

# edge color is tied or untied
ec = ['black','red','blue','green','purple']
eci=0

# shape is activation function
ms = ['.','s', '^','h']
mi=0

# size is L1 norm
s=50

for seed in range(1):
    for i in inits:
        s=100
    #print(i)
        for l in L1_norm:
            xi=0
            mi=0
        #print(l)
            for a in act_fun:
                m = ms[mi]
                eci=0
            #print(a)
                for t in tied:
                    name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                    print(name)
                    model_temp = model_dict_seq2[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'grey', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_seq2CTRL[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'pink', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_pre[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'black', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_preCTRL[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'red', marker = m, edgecolor = ec[eci], s=s)
                    eci = eci+1
                mi = mi+1
            s=s+250
        c = 'grey'
# Out:
# ad_glorot_uniform_0_sigmoid_tiedTrue571
# ad_glorot_uniform_0_tanh_tiedTrue571
# ad_glorot_uniform_0_relu_tiedTrue571
# ad_glorot_uniform_1e-05_sigmoid_tiedTrue571
# ad_glorot_uniform_1e-05_tanh_tiedTrue571
# ad_glorot_uniform_1e-05_relu_tiedTrue571
# ad_glorot_normal_0_sigmoid_tiedTrue571
# ad_glorot_normal_0_tanh_tiedTrue571
# ad_glorot_normal_0_relu_tiedTrue571
# ad_glorot_normal_1e-05_sigmoid_tiedTrue571
# ad_glorot_normal_1e-05_tanh_tiedTrue571
# ad_glorot_normal_1e-05_relu_tiedTrue571
