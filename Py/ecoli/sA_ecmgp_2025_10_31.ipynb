# %%
import run_model_preT
import run_model
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#from imp import reload
from importlib import reload
import Adage
from scipy.stats import hypergeom
import csv
import time
import random
# Out:
# 2025-11-01 19:07:30.218573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762038452.112129 2681903 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762038452.366870 2681903 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762038454.666693 2681903 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762038454.666809 2681903 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762038454.666822 2681903 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762038454.666829 2681903 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-01 19:07:34.858521: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# True

# %%
import tensorflow as tf

print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())
# Out:
# Num CPUs Available:  1
# Num GPUs Available:  1
# True

# %%
# for dev purposes, while updating run_model.py need to reload
# for dev purposes, while updating run_model.py need to reload
reload(run_model_preT)
reload(run_model)
reload(Adage)

# %%
run_model_preT.tune_model('../data_files/ecmgp_lcn01.csv',100)
# Out:
# KeyboardInterrupt

# %% [markdown]
# ## Base features (from ADAGE)
#
# For the sake of this efficiency, starting with the following parameters:
#
# * hidden features: 300
# * epochs: 500
# * curruption: 0.01
# * batchs zie: 10
# * validatoin split: 0.1
# * activation: sigmoid
# * objective: binary cross-entropy

# %%
#adage_comp = pandas.read_csv('data_files/ADAGE_compendium.csv')
all_comp = np.loadtxt(open('../data_files/ecmgp_lcn01.csv', "rb"),delimiter=',',skiprows = 1)
gene_num = np.size(all_comp, 0)
samp_num = np.size(all_comp, 1)
print(gene_num, samp_num)
fig = sns.histplot(all_comp.flatten(), bins = 50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: '"0ed86576d343ce011a61773e0620e335_1041"'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 #adage_comp = pandas.read_csv('data_files/ADAGE_compendium.csv')
# ----> 2 all_comp = np.loadtxt(open('../data_files/ecmgp_lcn01.csv', "rb"),delimiter=',',skiprows = 1)
#       3 gene_num = np.size(all_comp, 0)
#       4 samp_num = np.size(all_comp, 1)
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# File /hpc/group/ohlab/doingg/miniconda3/envs/tfkg/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1036, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1033     data = _preprocess_comments(data, comments, encoding)
#    1035 if read_dtype_via_object_chunks is None:
# -> 1036     arr = _load_from_filelike(
#    1037         data, delimiter=delimiter, comment=comment, quote=quote,
#    1038         imaginary_unit=imaginary_unit,
#    1039         usecols=usecols, skiplines=skiplines, max_rows=max_rows,
#    1040         converters=converters, dtype=dtype,
#    1041         encoding=encoding, filelike=filelike,
#    1042         byte_converters=byte_converters)
#    1044 else:
#    1045     # This branch reads the file into chunks of object arrays and then
#    1046     # casts them to the desired actual dtype.  This ensures correct
#    1047     # string-length and datetime-unit discovery (like `arr.astype()`).
#    1048     # Due to chunking, certain error reports are less clear, currently.
#    1049     if filelike:
#
# ValueError: could not convert string '"0ed86576d343ce011a61773e0620e335_1041"' to float64 at row 0, column 1.

# %%
#adage_comp = pandas.read_csv('data_files/ADAGE_compendium.csv')
all_comp = np.loadtxt(open('../data_files/ecmgp_lcn01.csv', "rb"),delimiter=',',skiprows = 1)
gene_num = np.size(all_comp, 0)
samp_num = np.size(all_comp, 1)
print(gene_num, samp_num)
fig = sns.histplot(all_comp.flatten(), bins = 50)

# %%
list(range(91+571,100+571))
# Out:
# [662, 663, 664, 665, 666, 667, 668, 669, 670]

# %%
comps = ["ecmgp_lcn01"]





model_dict_post = {}

stime = time.time()
ltime = 0
c = 0



seeds = list(range(91,100))
#seeds = random.sample(range(10000), 10)

for comp in comps:
    for seed in seeds:
        name = 'ad_' + comp + '_2025_09_01_' + str(seed+571)
        print(name)
        ttime = time.time()
        mseq = run_model.run_model('../data_files/ecmgp_lcn01.csv',
                                                  seed=seed+571,
                                                  enc_dim = 450,
                                                  kl1=0,
                                                  kl2=0,
                                                  act = "tanh",
                                                  act2="tanh",
                                                  tied = True,
                                                  epochs=100,
                                                  init="glorot_uniform",
                                                  batch_size=15,
                                                  dropout = 0,
                                                  mm = 0.6,
                                                  lr = 0.5)
       
        model_dict_post[name] = mseq
        ltime = ((time.time() - ttime) + ltime)
        c+=1

rtime = time.time() - stime
# Out:
# ad_ecmgp_lcn01_2025_09_01_662
# tied
# I0000 00:00:1762038585.793558 2681903 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30375 MB memory:  -> device: 0, name: NVIDIA RTX 5000 Ada Generation, pci bus id: 0000:13:00.0, compute capability: 8.9
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762038593.042014 2682342 service.cc:152] XLA service 0x55c37bf62e60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762038593.042089 2682342 service.cc:160]   StreamExecutor device (0): NVIDIA RTX 5000 Ada Generation, Compute Capability 8.9
# 2025-11-01 19:09:53.289997: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1762038593.674329 2682342 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-11-01 19:09:55.072105: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-01 19:09:55.887119: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-01 19:09:56.231404: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-01 19:09:56.546469: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-01 19:09:56.679420: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-11-01 19:09:56.695624: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 148 bytes spill stores, 148 bytes spill loads
#  63/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0438
# I0000 00:00:1762038598.609612 2682342 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 945/968 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174
# 2025-11-01 19:10:01.859037: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_22', 148 bytes spill stores, 148 bytes spill loads
#
# 2025-11-01 19:10:02.129150: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-01 19:10:02.521356: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-01 19:10:02.623578: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-01 19:10:02.717185: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_195', 16 bytes spill stores, 16 bytes spill loads
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173
# 2025-11-01 19:10:04.810870: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17', 148 bytes spill stores, 148 bytes spill loads
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0173 - val_loss: 0.0121
# Epoch 2/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 3/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 4/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 5/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0107 - val_loss: 0.0107
# Epoch 6/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 7/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 8/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 9/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 10/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 11/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 12/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 13/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 14/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 15/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 16/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 17/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 18/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 19/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 20/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 21/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 22/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 23/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 24/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 25/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 26/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 27/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 28/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 29/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 30/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 31/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 32/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 33/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 34/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 36/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 37/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 38/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 39/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 40/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 41/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 42/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 43/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 44/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 46/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 47/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 48/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 49/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 50/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 51/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 52/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 53/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 54/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 55/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 57/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 58/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 59/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 60/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 61/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 62/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 63/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 64/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 65/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 66/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 67/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 68/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 69/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 70/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 71/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 72/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 73/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 74/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 75/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 76/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 77/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 78/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 79/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 80/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 81/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 82/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 83/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 84/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 85/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 86/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 87/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 88/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 89/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 90/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 91/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 92/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 93/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 94/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 95/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 96/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 97/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 98/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 99/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0091 - val_loss: 0.0094
# Epoch 100/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0091 - val_loss: 0.0094
# fitted
# ad_ecmgp_lcn01_2025_09_01_663
# tied
# Epoch 1/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0175 - val_loss: 0.0120
# Epoch 2/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 3/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 4/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 5/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - val_loss: 0.0107
# Epoch 6/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 7/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0105
# Epoch 8/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 9/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 10/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 11/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 12/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 13/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 14/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 15/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 16/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 17/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 18/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 19/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 20/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 21/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 22/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 23/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 24/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 25/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 26/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 27/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 28/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 29/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 30/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 31/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 32/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 33/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 34/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 36/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 37/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 38/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 39/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 40/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 41/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 42/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 43/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 44/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 46/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 47/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 48/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 49/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 50/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 51/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 52/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 53/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 54/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 55/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 57/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 58/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 59/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 60/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 61/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 62/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 63/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 64/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 65/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 66/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 67/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 68/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 69/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 70/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 71/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 72/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 73/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 74/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 75/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 76/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 77/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 78/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 79/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 80/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 81/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 82/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 83/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 84/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 85/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 86/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 87/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 88/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 89/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 90/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 91/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 92/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 93/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 94/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 95/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 96/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 97/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 98/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 99/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 100/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# fitted
# ad_ecmgp_lcn01_2025_09_01_664
# tied
# Epoch 1/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0174 - val_loss: 0.0120
# Epoch 2/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0117 - val_loss: 0.0115
# Epoch 3/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 4/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 5/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0108 - val_loss: 0.0107
# Epoch 6/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 7/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 8/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 9/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 10/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 11/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 12/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 13/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 14/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 15/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 16/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 17/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0101
# Epoch 18/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 19/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 20/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 21/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 22/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 23/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 24/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 25/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 26/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 27/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 28/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 29/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 30/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 31/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 32/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 33/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 34/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 36/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 37/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 38/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 39/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 40/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 41/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 42/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 43/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 44/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 46/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 47/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 48/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 49/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 50/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 51/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 52/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 53/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 54/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 55/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 57/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 58/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 59/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 60/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 61/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 62/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 63/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 64/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 65/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 66/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 67/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 68/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 69/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 70/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 71/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 72/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 73/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 74/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 75/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 76/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 77/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 78/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 79/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 80/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 81/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 82/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 83/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 84/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 85/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 86/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 87/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 88/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 89/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 90/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 91/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 92/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 93/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 94/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 95/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 96/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 97/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 98/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 99/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 100/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# fitted
# ad_ecmgp_lcn01_2025_09_01_665
# tied
# Epoch 1/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0174 - val_loss: 0.0121
# Epoch 2/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0117 - val_loss: 0.0114
# Epoch 3/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 4/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 5/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0108 - val_loss: 0.0107
# Epoch 6/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 7/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0105
# Epoch 8/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 9/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 10/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 11/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 12/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 13/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 14/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 15/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 16/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 17/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 18/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 19/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 20/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 21/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 22/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 23/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 24/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 25/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 26/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 27/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 28/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 29/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 30/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 31/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 32/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 33/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 34/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 36/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 37/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 38/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 39/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 40/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 41/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 42/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 43/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 44/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 46/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 47/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 48/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 49/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 50/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 51/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 52/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 53/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 54/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 55/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 57/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 58/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 59/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 60/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 61/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 62/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 63/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 64/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 65/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 66/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 67/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 68/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 69/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 70/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 71/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 72/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 73/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 74/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 75/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 76/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 77/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 78/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 79/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 80/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 81/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 82/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 83/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 84/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 85/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 86/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 87/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 88/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 89/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 90/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 91/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 92/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 93/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 94/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 95/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 96/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 97/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 98/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 99/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 100/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# fitted
# ad_ecmgp_lcn01_2025_09_01_666
# tied
# Epoch 1/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0173 - val_loss: 0.0120
# Epoch 2/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0116 - val_loss: 0.0115
# Epoch 3/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 4/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 5/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0108 - val_loss: 0.0107
# Epoch 6/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 7/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 8/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 9/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 10/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 11/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 12/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 13/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 14/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 15/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 16/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 17/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 18/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 19/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 20/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 21/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 22/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 23/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 24/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 25/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 26/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 27/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 28/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 29/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 30/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 31/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 32/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 33/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 34/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 36/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 37/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 38/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 39/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 40/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 41/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 42/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 43/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 44/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 46/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 47/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 48/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 49/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 50/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 51/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 52/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 53/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 54/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 55/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 57/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 58/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 59/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 60/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 61/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 62/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 63/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 64/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 65/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 66/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 67/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 68/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 69/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 70/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 71/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 72/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 73/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 74/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 75/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 76/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 77/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 78/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 79/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 80/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 81/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 82/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 83/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 84/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 85/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 86/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 87/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 88/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 89/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 90/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 91/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 92/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 93/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 94/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 95/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 96/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 97/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# ...
# Epoch 20/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 21/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 22/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 23/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 24/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 25/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 26/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 27/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 28/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 29/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 30/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 31/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 32/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 33/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 34/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 36/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 37/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 38/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 39/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 40/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 41/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 42/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 43/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 44/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 46/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 47/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 48/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 49/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 50/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 51/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 52/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 53/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 54/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 55/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 57/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 58/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 59/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 60/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 61/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 62/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 63/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 64/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 65/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 66/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 67/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 68/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 69/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 70/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 71/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 72/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 73/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 74/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 75/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 76/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 77/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 78/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 79/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 80/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 81/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 82/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 83/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 84/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 85/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 86/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 87/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 88/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 89/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 90/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 91/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 92/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 93/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 94/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 95/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 96/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 97/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 98/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 99/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 100/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0091 - val_loss: 0.0094
# fitted
# ad_ecmgp_lcn01_2025_09_01_670
# tied
# Epoch 1/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0174 - val_loss: 0.0121
# Epoch 2/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0117 - val_loss: 0.0115
# Epoch 3/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 4/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 5/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0108 - val_loss: 0.0107
# Epoch 6/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 7/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0105
# Epoch 8/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 9/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 10/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 11/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 12/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 13/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 14/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 15/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 16/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 17/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 18/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 19/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 20/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 21/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 22/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 23/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 24/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 25/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 26/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 27/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 28/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 29/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 30/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 31/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 32/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 33/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 34/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 35/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 36/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0098
# Epoch 37/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 38/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 39/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 40/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 41/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 42/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 43/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 44/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 45/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 46/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 47/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 48/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 49/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 50/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 51/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 52/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 53/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 54/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 55/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 57/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 58/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 59/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 60/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 61/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 62/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 63/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 64/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 65/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 66/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 67/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 68/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 69/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 70/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 71/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 72/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 73/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 74/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 75/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 76/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 77/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 78/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 79/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 80/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 81/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 82/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 83/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 84/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 85/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 86/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0095
# Epoch 87/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 88/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 89/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 90/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 91/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 92/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 93/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 94/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 95/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 96/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 97/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 98/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0091 - val_loss: 0.0094
# Epoch 99/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0091 - val_loss: 0.0094
# Epoch 100/100
# 968/968 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0094
# fitted

# %%
print(rtime)
print(c)
print(ltime / c)
print(rtime / 60)
# Out:
# 2296.432013273239
# 10
# 229.64061329364776
# 38.273866887887316

# %%
len(comps)

# %%
model_dict = model_dict_post

xd = len(comps) + 1
yd = len(seeds)
fig, ax = plt.subplots(xd, yd,figsize=(xd*10 ,yd *1))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0


for comp in comps:
    xi=0
    for seed in seeds:
        name = 'ad_' + comp + '_2025_09_01_' + str(seed+571)
        model_temp = model_dict[name]
        ax[yi,xi].plot(list(range(0,100)), model_temp.loss, linewidth=1, markersize=2, color = 'orange')
        ax[yi,xi].plot(list(range(0,100)), model_temp.val_loss, linewidth=1, markersize=2, color = 'red')
        ax[yi,xi].set(title = name, xlabel = 'Epochs', ylabel = 'Loss')
        xi+=1
    yi+=1

# %%
model_dict = model_dict_pre

xd = len(comps)
yd = len(seeds)
fig, ax = plt.subplots(xd, yd,figsize=(xd*3 ,yd *5))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0


for comp in comps:
    xi=0
    for seed in seeds:
        name = 'ad_' + comp + '_2025_08_15_' + str(seed+571)
        model_temp = model_dict[name]
        ax[yi,xi].plot(list(range(0,10)), model_temp.loss, linewidth=1, markersize=2, color = 'orange')
        ax[yi,xi].plot(list(range(0,10)), model_temp.val_loss, linewidth=1, markersize=2, color = 'red')
        ax[yi,xi].set(title = name, xlabel = 'Epochs', ylabel = 'Loss')
        xi+=1
    yi+=1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.005, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2CTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_seq2CTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_pre[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
yd = len(inits) * len(L1_norm)
xd = len(act_fun) * len(tied)
fig, ax = plt.subplots(xd, yd,figsize=(yd*8 ,xd *4))
fig.tight_layout(pad=3.0)

xi = 0
yi = 0
for l in L1_norm:
    for i in inits:
        xi = 0
        for a in act_fun:
            for t in tied:
                name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                #print(name)
                model_temp = model_dict_preCTRL[name]
                for node in range(0,100):
                    sns.histplot(model_temp.weights[node], #[model_temp.weights[node] > 0],
                        ax=ax[xi,yi],
                        #hist=True,
                        binwidth = 0.01, 
                        #stat="density",
                        kde=False
                        #rug=False
                                )
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*2.5)
                ax[xi,yi].axvline(x = np.std(model_temp.weights)*-2.5)
                ax[xi,yi].set(title = name)
                xi = xi+1
        yi=yi+1

# %%
model_temp = model_dict_seq2
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_seq2[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_seq2[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done') 

model_temp = model_dict_seq2CTRL
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_seq2CTRL[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_seq2CTRL[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done') 


model_temp = model_dict_pre
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_pre[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_pre[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done')


model_temp = model_dict_preCTRL
#del model_temp['tf_adage']
for m in model_temp:
    print(m)
    model_dict_preCTRL[m].set_hwg_cutoff(2.5)
    #model_dict_seq2[m].set_op('../node_interpretation/operons_format.txt')
    #print('op done')
    model_dict_preCTRL[m].set_kegg('../node_interpretation/sepi_pan_KEGG_format.txt') 
    #print('kegg done')
    #model_dict_seq2[m].set_go('../node_interpretation/manual_GO_BP_terms.txt') 
    #print('go done')
    #model_dict_seq2[m].set_reg('../node_interpretation/regulons_format.txt')
    #print('reg done')
print('dict done')

# %%
plimk=5
plimg=5
plimr=5
plimo=5
xd=2
yd=2
fig, ax = plt.subplots(xd,yd,figsize=(xd*8 ,yd *8))
#x = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(0) > 0).sum()
#y = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(1) > 0).sum()
#ax[0,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,0].set(title = 'KEGG', xlabel = 'Total Paths', ylabel = 'Sigs with Paths')

#x = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(1) > 0).sum()
#ax[0,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,1].set(title = 'GO', xlabel = 'Total BP', ylabel = 'Sigs with BP')

#x = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(1) > 0).sum()
#ax[1,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,0].set(title = 'Regulons', xlabel = 'Total Regs', ylabel = 'Sigs with Regs')

#x = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(1) > 0).sum()
#ax[1,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,1].set(title = 'Operons', xlabel = 'Total Operons', ylabel = 'Sigs with Operons')

xi = 0
yi = 0
c = 'grey'

# edge color is tied or unties
ec = ['black','red','blue','green','purple']
eci=0

# shape is activation function
ms = ['.','s', '^','h']
mi=0

# size is L1 norm
s=50

for seed in range(1):
    for i in inits:
        s=100
    #print(i)
        for l in L1_norm:
            xi=0
            mi=0
        #print(l)
            for a in act_fun:
                m = ms[mi]
                eci=0
            #print(a)
                for t in tied:
                    name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                    print(name)
                    model_temp = model_dict_seq2[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax[0,0].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    #model_temp = model_dict_seq2CTRL[name]
                    #x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    #y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    #ax[0,1].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_pre[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax[1,0].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    
                    #model_temp = model_dict_preCTRL[name]
                    #x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    #y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    #ax[1,1].scatter(x, y, c = c, marker = m, edgecolor = ec[eci], s=s)
                    #eci = eci+1
                mi = mi+1
            s=s+250
        c = 'grey'

# %%
plimk=5
plimg=5
plimr=5
plimo=5
xd=1
yd=1
fig, ax = plt.subplots(xd,yd,figsize=(xd*8 ,yd *8))
#x = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(0) > 0).sum()
#y = ((model_dict_seq2['tf_adage'].kegg_ps > plimk).sum(1) > 0).sum()
#ax[0,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,0].set(title = 'KEGG', xlabel = 'Total Paths', ylabel = 'Sigs with Paths')

#x = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].go_ps > plimg).sum(1) > 0).sum()
#ax[0,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[0,1].set(title = 'GO', xlabel = 'Total BP', ylabel = 'Sigs with BP')

#x = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].regs_ps > plimr).sum(1) > 0).sum()
#ax[1,0].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,0].set(title = 'Regulons', xlabel = 'Total Regs', ylabel = 'Sigs with Regs')

#x = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(0) > 0).sum()
#y = ((model_dict_da_reps['tf_adage'].ops_ps > plimo).sum(1) > 0).sum()
#ax[1,1].scatter(x, y, c = 'yellow', marker = '*', edgecolor ='black', s=1000)
#ax[1,1].set(title = 'Operons', xlabel = 'Total Operons', ylabel = 'Sigs with Operons')

xi = 0
yi = 0
c = 'grey'

# edge color is tied or untied
ec = ['black','red','blue','green','purple']
eci=0

# shape is activation function
ms = ['.','s', '^','h']
mi=0

# size is L1 norm
s=50

for seed in range(1):
    for i in inits:
        s=100
    #print(i)
        for l in L1_norm:
            xi=0
            mi=0
        #print(l)
            for a in act_fun:
                m = ms[mi]
                eci=0
            #print(a)
                for t in tied:
                    name = 'ad_' + i + '_' + str(l) + '_' + a + '_tied' + str(t) + str(571)
                    print(name)
                    model_temp = model_dict_seq2[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'grey', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_seq2CTRL[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'pink', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_pre[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'black', marker = m, edgecolor = ec[eci], s=s)
                    
                    model_temp = model_dict_preCTRL[name]
                    x = ((model_temp.kegg_ps > plimk).sum(0) > 0).sum()
                    y = ((model_temp.kegg_ps > plimk).sum(1) > 0).sum()
                    ax.scatter(x, y, c = 'red', marker = m, edgecolor = ec[eci], s=s)
                    eci = eci+1
                mi = mi+1
            s=s+250
        c = 'grey'
